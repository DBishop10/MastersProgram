# %%
import pandas as pd
import numpy as np
from data_pipeline import Pipeline

# %%
data = pd.read_csv('data/CreditCardFraudFourYears.csv')

# %%
pipeline = Pipeline()
transformed_df = pipeline.transform(data)

# %%
for column in transformed_df.columns:
    if pd.api.types.is_bool_dtype(transformed_df[column]):
        transformed_df[column] = transformed_df[column].astype(int)
    if pd.api.types.is_integer_dtype(transformed_df[column]):
        transformed_df[column] = transformed_df[column].astype(float)
transformed_df.dtypes
# Out:
# total_daily_transactions          float64
# total_daily_fraud_transactions    float64
# hour_0                            float64
# hour_1                            float64
# hour_2                            float64
# hour_3                            float64
# hour_4                            float64
# hour_5                            float64
# hour_6                            float64
# hour_7                            float64
# hour_8                            float64
# hour_9                            float64
# hour_10                           float64
# hour_11                           float64
# hour_12                           float64
# hour_13                           float64
# hour_14                           float64
# hour_15                           float64
# hour_16                           float64
# hour_17                           float64
# hour_18                           float64
# hour_19                           float64
# ...

# %%
transformed_df['mm_dd'] = transformed_df.index.strftime('%m/%d')

transformed_df.head()
# Out:
#             total_daily_transactions  total_daily_fraud_transactions  hour_0  \
# trans_date
# 2018-01-01                    1016.0                             0.0    89.0
# 2018-01-02                    1193.0                             0.0   101.0
# 2018-01-03                    1131.0                             0.0    77.0
# 2018-01-04                    1170.0                             0.0    72.0
# 2018-01-05                    1851.0                             7.0   150.0
#
#             hour_1  hour_2  hour_3  hour_4  hour_5  hour_6  hour_7  ...  \
# trans_date                                                          ...
# 2018-01-01    88.0    97.0    76.0    82.0    82.0    73.0    95.0  ...
# 2018-01-02   116.0   107.0   105.0    89.0   110.0    90.0    85.0  ...
# 2018-01-03    96.0    91.0    98.0    83.0   106.0    92.0    96.0  ...
# 2018-01-04   106.0    95.0   106.0   105.0    99.0   121.0    93.0  ...
# ...

# %%
average_daily_data = transformed_df.groupby('mm_dd').mean().reset_index()
average_daily_data.set_index('mm_dd', inplace=True)

# %%
average_daily_data.to_csv('average_daily_data.csv')
