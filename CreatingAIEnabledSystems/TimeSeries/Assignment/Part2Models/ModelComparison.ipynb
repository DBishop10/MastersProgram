# %% [markdown]
# # Model Comparison

# %% [markdown]
# ## Traditional

# %% [markdown]
# ![Screenshot 2024-04-05 145109.png](attachment:4adf6fa9-fa7e-4286-a98a-bc57f71a965d.png)

# %% [markdown]
# As we can see above the model doesn't do a very good job at determining fraud

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# ![Screenshot 2024-04-05 145059.png](attachment:4cc4a274-bc4c-4c75-8970-4d4b6e5a770c.png)

# %% [markdown]
# As we can note in the graph above, the deep model also doesn't do a great job at forecasting only fraud

# %% [markdown]
# ## Final Thoughts on these modesl
#
# Niether of these models did particularly well compared to how they did in part 1, why? My best thought on this is that the fraud data was a lot more sparse and a lot more sparadic than the total transactions overall. We can actually see this in the graphs comparing predicted vs actual. This is a drastic difference to the much more stable graphs of total transactions.
