# %% [markdown]
# # Model Comparison

# %% [markdown]
# ## Traditional

# %% [markdown]
# ![Screenshot 2024-04-05 113007.png](attachment:fdabc3ae-f408-46a0-a390-dab71a95e5a1.png)

# %% [markdown]
# As we can see above the model does an amazing job at determining the next year's data from the test data provided.

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# ![Screenshot 2024-04-05 135624.png](attachment:5b8e0f32-c814-4390-bdcc-e7eca58ad933.png)

# %% [markdown]
# As we can note in the graph above, the deep model does an incredible job at forecasting the amount of transactions for this time period.

# %% [markdown]
# ## Final Thoughts on these modesl
#
# These models both do a near perfect job of forecasting the data.
